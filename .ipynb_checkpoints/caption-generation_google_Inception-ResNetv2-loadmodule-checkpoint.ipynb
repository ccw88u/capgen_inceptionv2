# %%
import glob
#piclst = glob.glob('data/Flickr30k/flickr30k_images/flickr30k_images/*.jpg')
piclst = glob.glob('data/Flicker8k_Dataset/*.jpg')
ranpics = getrandom_fromlst(piclst, radnum=10)
#print(ranpics)
cn = 1
for fp in ranpics:
    print('No.%s' % cn)
    read_img_manview(fp)
    #resize_image(fp, '/tmp/testvgg.jpg', rswidth=299, rsheight=299)
    ##不縮直接跑 
    photo = extract_features_onepic(fp)    
    generate_desc_transzhtw(model, tokenizer, photo, max_length)    
    ##縮圖跑
    #photo = extract_features_onepic('/tmp/testvgg.jpg')    
    #generate_desc_transzhtw(model, tokenizer, photo, max_length)
    cn += 1
# Out:
# No.1
# (500, 333, 3)
# Eng  man in red shirt is climbing on the edge of rock
# zh-TW 紅襯衫的男子正在攀登岩石邊緣
# No.2
# (331, 500, 3)
# Eng  small dog is chasing after ball on the grass
# zh-TW 小狗在草地上追逐球
# No.3
# (311, 500, 3)
# Eng  two dogs are playing in grassy field
# zh-TW 兩隻狗在草地上玩耍
# No.4
# (500, 333, 3)
# Eng  man in red hat and khaki pants is on rocky cliff
# zh-TW 紅色帽子和卡其色褲子的人是在岩石峭壁上
# No.5
# (346, 500, 3)
# Eng  woman in red shirt and white hat is painting picture of young woman in red and yellow shirt
# zh-TW 穿著紅色襯衫和白色帽子的女人繪畫紅色和黃色襯衫的年輕女子的圖片
# No.6
# (333, 500, 3)
# Eng  white dog is jumping on the white dog
# zh-TW 白色的狗在白色的狗上跳躍
# No.7
# (375, 500, 3)
# Eng  boy on swing
# zh-TW 男孩在鞦韆上
# No.8
# (375, 500, 3)
# Eng  woman in hat and hat is sitting next to woman in hat and looking up
# zh-TW 帽子和帽子的女人坐在旁邊的帽子和查找的女人
# No.9
# (333, 500, 3)
# Eng  football team in red and white are jumping on the football
# zh-TW 紅色和白色的橄欖球隊正在跳上橄欖球
# No.10
# (333, 500, 3)
# Eng  two men in white uniforms are playing cricket in stadium
# zh-TW 兩名身穿白色制服的男子正在體育場打板球

# %%
#piclst = glob.glob('data/Flickr30k/flickr30k_images/flickr30k_images/*.jpg')
piclst = glob.glob('data_30k/flickr30k_images/*.jpg')
ranpics = getrandom_fromlst(piclst, radnum=10)
#print(ranpics)
cn = 1
for fp in ranpics:
    print('No.%s' % cn)
    read_img_manview(fp)
    #resize_image(fp, '/tmp/testvgg.jpg', rswidth=299, rsheight=299)
    ##不縮直接跑 
    photo = extract_features_onepic(fp)    
    generate_desc_transzhtw(model, tokenizer, photo, max_length)    
    ##縮圖跑
    #photo = extract_features_onepic('/tmp/testvgg.jpg')    
    #generate_desc_transzhtw(model, tokenizer, photo, max_length)
    cn += 1
# Out:
# No.1
# (333, 500, 3)
# Eng  little boy in red shirt and khaki pants is laying on white couch
# zh-TW 紅色襯衫和卡其色褲子的小男孩躺在白色的沙發上
# No.2
# (333, 500, 3)
# Eng  brown and white dog runs in the grass and looks
# zh-TW 棕色和白色的狗跑在草地上，看起來
# No.3
# (375, 500, 3)
# Eng  two children are playing with boxes in kitchen
# zh-TW 兩個孩子在廚房玩盒子
# No.4
# (360, 500, 3)
# Eng  woman with blue hat and headwear is sitting at table
# zh-TW 藍色的帽子和頭飾的女人坐在桌前
# No.5
# (375, 500, 3)
# Eng  group of children in the middle of brick building
# zh-TW 小組在磚瓦房中間的孩子
# No.6
# (500, 400, 3)
# Eng  bride and groom pose for picture in formal clothing
# zh-TW 新娘和新郎構成正式服裝中的圖片
# No.7
# (500, 400, 3)
# Eng  young boy wearing blue is playing in the sand on the beach
# zh-TW 穿著藍色的小男孩在沙灘上玩沙
# No.8
# (500, 313, 3)
# Eng  girl in pink shirt is blowing bubbles
# zh-TW 穿粉紅色襯衫的女孩吹泡泡
# No.9
# (333, 500, 3)
# Eng  the woman is standing on the wooden bench and waving around her makeup
# zh-TW 女人站在木凳上，在她的化妝周圍揮舞著
# No.10
# (500, 375, 3)
# Eng  woman in white shirt and dark glasses is standing by some people who are wearing white shirts
# zh-TW 白襯衫和墨鏡的女人正站在一些身穿白襯衫的人身上
